# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')

sns.scatterplot(data=tips, x= "total_bill", y="tip",hue="size")
plt.title("Total Bill vs Tip")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
sns.barplot(data = tips, x="day", y="total_bill", hue='sex')
plt.show()

# %%
sns.histplot(data=tips, x='total_bill', kde=True)
plt.title('Histogram with KDE in SeaBorn')
plt.show()

# %%
flights = sns.load_dataset('flights')
pivot_flights = flights.pivot_table(index='month', columns='year', values='passengers')
# Convert the data to integers
pivot_flights_int = pivot_flights.astype(int)
# Create heatmap with values on each block
plt.figure(figsize=(12,6))
sns.heatmap(pivot_flights_int, annot=True,cmap='coolwarm', fmt='d')

plt.title('Heatmap of Flights')
plt.show()

# %%
iris = sns.load_dataset('iris')
#pearplot
sns.pairplot(iris, hue='species', palette='Dark2')

# %%
sns.lmplot(data=tips, x='total_bill',y='tip',hue='size')

# %%
from bokeh.plotting import figure, output_notebook, show

output_notebook()

x=[1,2,3,4,5]
y=[6,7,2,4,5]

p=figure(title="Basic scatter plot")

p.circle(x,y,size=10, color="navy", alpha=0.5)

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a4a7c4b6-d38b-400a-b4f6-394652e2086a">Loading BokehJS ...</span>
#     </div>
#   <div id="c3068fab-6a4e-4980-ba81-1589225b1bfd" data-root-id="p1291" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource
from bokeh.transform import factor_cmap
import pandas as pd

output_notebook()
data = pd.DataFrame({'fruits':['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries'], 'values':[5,3,4,2,4,6]})

p = figure(x_range=data['fruits'], title = "bar chart example", width=400)
source = ColumnDataSource(data)
p.vbar(x='fruits', top='values', width=0.9, source=source, legend_field="fruits", line_color='white')

p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = 10

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cf063440-1a3b-4e8c-87f0-5966929186b1">Loading BokehJS ...</span>
#     </div>
#   <div id="f507bef9-2a0d-4e32-9083-ef9b8b9f1861" data-root-id="p1473" style="display: contents;"></div>

# %%
from dateutil import parser

dt = parser.parse("Jul 20 1969  1:33PM")
print(dt)
# Out:
# 1969-07-20 13:33:00

# %%
from datetime import datetime
delta_t =(datetime.now()-dt)
print(f"{delta_t} since the first human moon landing")
# Out:
# 19813 days, 22:28:39.343956 since the first human moon landing

# %%
import numpy as np
import pandas as pd
np.random.seed(0)
def random_walk(n_steps):
    step = 0.5 - np.random.rand(n_steps)
    return np.cumsum(step)
dates = pd.date_range('1/1/2019','12/31/2019', freq='D')
data = {'a':random_walk(365), 'b':random_walk(365), 'c':random_walk(365)}
df = pd.DataFrame(data, index=dates)
df.head(10)
# Out:
#                    a         b         c
# 2019-01-01 -0.048814  0.041396 -0.001063
# 2019-01-02 -0.264003 -0.182772  0.122548
# 2019-01-03 -0.366766 -0.081797  0.257636
# 2019-01-04 -0.411649 -0.485841  0.496731
# 2019-01-05 -0.335304 -0.675866  0.500761
# 2019-01-06 -0.481198 -0.875488  0.319021
# 2019-01-07 -0.418786 -0.703209  0.541681
# 2019-01-08 -0.810559 -0.959987  0.517301
# 2019-01-09 -1.274221 -1.096048  0.899921
# 2019-01-10 -1.157663 -0.836069  1.240075

# %%
dates_ET = pd.date_range('1/1/2019','12/31/2019', freq='D', tz='US/Eastern')
dates_ET[:5]
# Out:
# DatetimeIndex(['2019-01-01 00:00:00-05:00', '2019-01-02 00:00:00-05:00',
#                '2019-01-03 00:00:00-05:00', '2019-01-04 00:00:00-05:00',
#                '2019-01-05 00:00:00-05:00'],
#               dtype='datetime64[ns, US/Eastern]', freq='D')

# %%
df_ET = df.tz_localize('EUROPE/BERLIN')
df_ET.head()
# Out:
#                                   a         b         c
# 2019-01-01 00:00:00+01:00 -0.048814  0.041396 -0.001063
# 2019-01-02 00:00:00+01:00 -0.264003 -0.182772  0.122548
# 2019-01-03 00:00:00+01:00 -0.366766 -0.081797  0.257636
# 2019-01-04 00:00:00+01:00 -0.411649 -0.485841  0.496731
# 2019-01-05 00:00:00+01:00 -0.335304 -0.675866  0.500761

# %%
import xgboost as xgb
import matplotlib.pyplot as plt

model = xgb.XGBClasifier()
model.fit(X_train, y_train)

xgb.plot_importance(model)
plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import xgboost as xgb
import matplotlib.pyplot as plt

np.random.seed(0)
X_train = np.random.rand(100,5)
y_train = np.random.randint(0, 2, 100)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, random_state=42, test_size=0.2)

# Create the XGBClassifier: xg_cl
model = xgb.XGBClassifier()
model.fit(X_train, y_train)

# Plot the feature importances
xgb.plot_importance(model)
plt.show()

# %%
(df['a'].tz_localize('US/Eastern') -df['a'].tz_localize('Europe/Berlin')).head()
# Out:
# 2018-12-31 23:00:00+00:00   NaN
# 2019-01-01 05:00:00+00:00   NaN
# 2019-01-01 23:00:00+00:00   NaN
# 2019-01-02 05:00:00+00:00   NaN
# 2019-01-02 23:00:00+00:00   NaN
# Name: a, dtype: float64

# %%
print(df['a'].tz_localize('US/Eastern'))
# Out:
# 2019-01-01 00:00:00-05:00   -0.048814
# 2019-01-02 00:00:00-05:00   -0.264003
# 2019-01-03 00:00:00-05:00   -0.366766
# 2019-01-04 00:00:00-05:00   -0.411649
# 2019-01-05 00:00:00-05:00   -0.335304
#                                ...
# 2019-12-27 00:00:00-05:00    3.836372
# 2019-12-28 00:00:00-05:00    3.432389
# 2019-12-29 00:00:00-05:00    3.388583
# 2019-12-30 00:00:00-05:00    3.431671
# 2019-12-31 00:00:00-05:00    3.049630
# Name: a, Length: 365, dtype: float64
